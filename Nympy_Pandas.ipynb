# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\shama\\Data science'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'Untitled.ipynb']

# %%
os.makedirs("new Folder")

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'new Folder', 'Untitled.ipynb']

# %%
'''pythonvs vs excel
* limitation by size
* complex data transformation
* automation
* cross platform capabilities'''
# Out:
# 'pythonvs vs excel\n* limitation by size\n* complex data transformation\n* automation\n* cross platform capabilities'

# %%
''' dataframe has two axis x and y
i.e rows and columns'''
# Out:
# ' dataframe has two axis x and y\ni.e rows and columns'

# %%
''' excel ------------------>>   pandas
worksheet                        dataframes
column                           series
row heading                      index
row                              row
empty cell                       NaN'''
# Out:
# ' excel ------------------>>   pandas\nworksheet                        dataframes\ncolumn                           series\nrow heading                      index\nrow                              row\nempty cell                       NaN'

# %%
'''np.array([1,4],[2,5],[3,6])

       col1     col2
____________________
        1        4
        2        5
        3        6         '''
# Out:
# 'np.array([1,4],[2,5],[3,6])\n\n       col1     col2\n____________________\n        1        4\n        2        5\n        3        6         '

# %% [raw]
# import pandas as pd
# import numpy as np
#
# What is NumPy?
#
# NumPy (Numerical Python) is a Python library used for:
#
# Fast mathematical calculations
#
# Working with arrays (like lists, but faster and more powerful)
#
# Doing matrix computation (important for machine learning)
#
# 🔹 Example use:
#
# Adding numbers fast
#
# Working with 1D, 2D, or 3D arrays (vectors, matrices)
#
# Scientific and mathematical operations
#
#
# What is Pandas?
#
# Pandas is a Python library used for:
#
# Handling data tables (rows & columns)
#
# Data cleaning
#
# Data analysis and manipulation
#
# 🔹 Example use:
#
# Working with CSV, Excel, SQL data
#
# Filtering rows, selecting columns
#
# Handling missing values

# %% [markdown]
# 1  creating a dataframe from an array
#
# Why NumPy removes the commas?
#
# Because NumPy displays arrays in a compact mathematical format, similar to matrices:

# %%
#option 1 creating an array

# %%
import pandas as pd
import numpy as np
data=np.array([[1,4],[2,5],[3,6]])
print(data)
data1=np.array([1,2,3,4])
print(data1)
# Out:
# [[1 4]
#  [2 5]
#  [3 6]]
# [1 2 3 4]

# %%
#creating a dataframe
pd.DataFrame(data,index=['r1','r2','r3'],columns=['col1','col2'])
# Out:
#     col1  col2
# r1     1     4
# r2     2     5
# r3     3     6

# %% [raw]
# 2. Creating a DataFrame from a dictionary

# %%
#lists used forthis example
states=['karnataka','MP','UP','Maha']
population=[11,22,33,44]

# %%
dic={'states':states,'population':population}

# %%
print(dic)
# Out:
# {'states': ['karnataka', 'MP', 'UP', 'Maha'], 'population': [11, 22, 33, 44]}

# %%
pd.DataFrame(dic)
# Out:
#       states  population
# 0  karnataka          11
# 1         MP          22
# 2         UP          33
# 3       Maha          44

# %%
pd.DataFrame(dic,index=['r1','r2','r3','r4'])
# Out:
#        states  population
# r1  karnataka          11
# r2         MP          22
# r3         UP          33
# r4       Maha          44

# %% [raw]
# 3. CReating a Dataframe from a csv file

# %%
df=pd.read_csv('bestsellers with categories.csv')
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
#show first 5 row
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
#show last 5 rows
df.tail()
# Out:
#                                                   Name       Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 545          4.9     9413      8  2019      Fiction
# 546          4.7    14331      8  2016  Non Fiction
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %%
#show last n rows in a dataframe
df.tail(10)
# Out:
#                                                   Name         Author  \
# 540                                             Wonder  R. J. Palacio
# 541                                             Wonder  R. J. Palacio
# 542                                             Wonder  R. J. Palacio
# 543                                             Wonder  R. J. Palacio
# 544                                             Wonder  R. J. Palacio
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)    Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...    Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...    Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...    Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...    Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 540          4.8    21625      9  2013      Fiction
# 541          4.8    21625      9  2014      Fiction
# ...

# %%
#getting access to the shape attribute
df.shape
# Out:
# (550, 7)

# %%
#display n rows
pd.set_option('display.max_rows',100)
df = pd.read_csv('bestsellers with categories.csv')
print(df)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [raw]
# PANDAS
#
#
# ATTRIBUTES--THE VALUE ASSOCIATED WITH AN OBJECT  df.columns
# FUNCTION--- PYTHON BUILT-IN FUNCTIONS min(),max(),len()
# METHODS--- Afunction which is defined inside a class body

# %%
1  ATTRIIBUTES

# %%
df.index
# Out:
# RangeIndex(start=0, stop=550, step=1)

# %%
df.shape
# Out:
# (550, 7)

# %%
df.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
#data type of each column
df.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %%
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [raw]
# 2 METHODS

# %%
#showing first 5 columns
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
df.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %% [raw]
# 3 FUNCTIONS

# %%
#obtaining the length of the dataframe i.e no of rows
len(df)
# Out:
# 550

# %%
max(df)
# Out:
# 'Year'

# %%
max(df.index)
# Out:
# 549

# %%
#obtaining the data type
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#rounding the values of the dataset
round(df,0)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          5.0    17350      8  2016  Non Fiction
# 1                Stephen King          5.0     2052     22  2011      Fiction
# ...

# %% [raw]
# 1 SELECTING ONE COLUMN

# %% [raw]
# # 1.1 Syntax 1
# #select a column with[]
# df['Author']

# %%
#check out the data type of a column
type(df['Author'])
# Out:
# pandas.core.series.Series

# %%
df['Author'].head()
# Out:
# 0                    JJ Smith
# 1                Stephen King
# 2          Jordan B. Peterson
# 3               George Orwell
# 4    National Geographic Kids
# Name: Author, dtype: object

# %%
df['Author'].index
# Out:
# RangeIndex(start=0, stop=550, step=1)

# %% [raw]
# 1.2 SYNTAX

# %%
#select a column with .
df.Author
# Out:
# 0                      JJ Smith
# 1                  Stephen King
# 2            Jordan B. Peterson
# 3                 George Orwell
# 4      National Geographic Kids
#                  ...
# 545                 Jeff Kinney
# 546                 Jen Sincero
# 547                 Jen Sincero
# 548                 Jen Sincero
# 549                 Jen Sincero
# Name: Author, Length: 550, dtype: object

# %%
#select the same using []
df['Author']
# Out:
# 0                      JJ Smith
# 1                  Stephen King
# 2            Jordan B. Peterson
# 3                 George Orwell
# 4      National Geographic Kids
#                  ...
# 545                 Jeff Kinney
# 546                 Jen Sincero
# 547                 Jen Sincero
# 548                 Jen Sincero
# 549                 Jen Sincero
# Name: Author, Length: 550, dtype: object

# %% [raw]
# SELECT TWO OR MORE COLUMNS

# %%
#select 2 columns using [[]]
df[['Name','Author']]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author
# 0                    JJ Smith
# 1                Stephen King
# 2          Jordan B. Peterson
# 3               George Orwell
# 4    National Geographic Kids
# ..                        ...
# 545               Jeff Kinney
# 546               Jen Sincero
# ...

# %%
type(df[['Name','Author']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Price','Year','Name','Author']]
# Out:
#      Price  Year                                               Name  \
# 0        8  2016                      10-Day Green Smoothie Cleanse
# 1       22  2011                                  11/22/63: A Novel
# 2       15  2018            12 Rules for Life: An Antidote to Chaos
# 3        6  2017                             1984 (Signet Classics)
# 4       12  2019  5,000 Awesome Facts (About Everything!) (Natio...
# ..     ...   ...                                                ...
# 545      8  2019       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546      8  2016  You Are a Badass: How to Stop Doubting Your Gr...
# 547      8  2017  You Are a Badass: How to Stop Doubting Your Gr...
# 548      8  2018  You Are a Badass: How to Stop Doubting Your Gr...
# 549      8  2019  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author
# 0                    JJ Smith
# 1                Stephen King
# 2          Jordan B. Peterson
# ...

# %%
#we cannot select 2 or more columns with "."
df.'Author','Name'
# Out:
#   Cell In[85], line 2
#     df.'Author','Name'
#        ^
# SyntaxError: invalid syntax

# %% [raw]
# ADDING A NEW COLUMN

# %%
#1.1 Adding a new column with a scaler value


df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
#1.2 Adding a new column with an array
#The datafarme has 550 rows , so we neeed to create an array with 550 elements

# %%
#import numpy
import numpy as np

# %%
#create an array of 550 elements
language_score=np.arange(0,550)

# %%
len(language_score)
# Out:
# 550

# %%
df['Language Score']=language_score

# %%
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
#Create a random integer number between1 and 100
int_language_score=np.random.randint(1,100,size=550)
int_language_score
# Out:
# array([11, 71, 16, 96, 11, 84, 93, 84, 79, 22, 16, 20, 71, 26, 69, 85,  1,
#        29, 88, 92, 28, 25, 87, 76, 96, 36, 65, 42, 78, 81, 88, 75, 76, 48,
#        99, 69, 38, 88, 95, 72, 85, 55, 75, 28, 82, 89,  4, 48, 30,  7, 55,
#        30, 51, 91, 24, 74, 39, 94, 14, 38, 21,  7, 49, 20, 13, 30, 41, 85,
#        84, 57, 78, 74, 84, 11, 29, 36, 27, 79, 46, 96, 90, 72, 99, 14, 71,
#        80, 70, 45, 39, 58, 63, 40, 93, 19, 13, 53, 50, 80, 23, 19, 43, 94,
#        81, 32, 24, 10, 97, 96, 20, 67,  4, 35, 94, 22, 42, 36, 50,  7, 40,
#        50, 44, 51, 11, 33, 18, 69, 80, 45, 20, 83,  2, 50, 79, 58, 43, 78,
#        94, 69, 62, 45, 25,  1, 40, 39, 18, 46, 24, 75, 18, 40, 24, 23, 28,
#        67, 53,  7, 22, 78, 62, 23, 72, 28, 91, 89, 90, 42, 37, 69, 31, 90,
#        39, 65, 75, 39, 39, 13,  6, 25, 16, 26, 24,  5, 57, 82, 83, 46, 77,
#        80, 39, 96, 87,  3, 37, 11, 31, 35, 63, 71, 77, 44, 98, 27, 75, 93,
# ...

# %%
df['Language Score']=int_language_score

# %%
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# Create random float numbers  between 1 and 100
fl=np.random.uniform(1,100,size=550)
df['Language Score']=fl
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [raw]
# Adding a new column
# 1.1 assign()
#
# when to use assign?
# * Add multiple columns in a single line of code
# *when you need to overwrite the vaues of an existing columns(best practice)
#
# it returns a new object(a copy) with all the original columns in addition to the new ones

# %%
import numpy as np
#craete a random numbers for our new score columns

# %%
s1=np.random.randint(1,100,size=550)
s2=np.random.randint(1,100,size=550)

# %%
#create a series using the random numbers
se1=pd.Series(s1,index=np.arange(0,550))
se2=pd.Series(s2,index=np.arange(0,550))

# %%
se1
# Out:
# 0      43
# 1      75
# 2      13
# 3      92
# 4      86
#        ..
# 545    76
# 546     2
# 547     8
# 548    19
# 549    57
# Length: 550, dtype: int32

# %%
se2
# Out:
# 0      68
# 1      32
# 2      41
# 3      49
# 4      66
#        ..
# 545    24
# 546    73
# 547    60
# 548    54
# 549    49
# Length: 550, dtype: int32

# %%
#using assign() to add
df.assign(score1=se1,score2=se2)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
#1.2 insert()
df.insert(1,'test',se1)

# %%
df
# Out:
#                                                   Name  test  \
# 0                        10-Day Green Smoothie Cleanse    43
# 1                                    11/22/63: A Novel    75
# 2              12 Rules for Life: An Antidote to Chaos    13
# 3                               1984 (Signet Classics)    92
# 4    5,000 Awesome Facts (About Everything!) (Natio...    86
# ..                                                 ...   ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)    76
# 546  You Are a Badass: How to Stop Doubting Your Gr...     2
# 547  You Are a Badass: How to Stop Doubting Your Gr...     8
# 548  You Are a Badass: How to Stop Doubting Your Gr...    19
# 549  You Are a Badass: How to Stop Doubting Your Gr...    57
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# ...

# %%
df['Price'].sum()
# Out:
# np.int64(7205)

# %%
df['Price'].mean()
# Out:
# np.float64(13.1)

# %%
df['Price'].count()
# Out:
# np.int64(550)

# %%
df['Price'].min()
# Out:
# 0

# %%
df['Price'].max()
# Out:
# 105

# %%
df['Price'].std()
# Out:
# 10.84226197842238

# %%
df.describe()
# Out:
#              test  User Rating       Reviews       Price         Year  \
# count  550.000000   550.000000    550.000000  550.000000   550.000000
# mean    50.785455     4.618364  11953.281818   13.100000  2014.000000
# std     28.060327     0.226980  11731.132017   10.842262     3.165156
# min      1.000000     3.300000     37.000000    0.000000  2009.000000
# 25%     26.000000     4.500000   4058.000000    7.000000  2011.000000
# 50%     53.000000     4.700000   8580.000000   11.000000  2014.000000
# 75%     74.000000     4.800000  17253.250000   16.000000  2017.000000
# max     99.000000     4.900000  87841.000000  105.000000  2019.000000
#
#        Language Score
# count      550.000000
# mean        51.004604
# std         28.170370
# min          1.504964
# 25%         25.843301
# 50%         52.200282
# 75%         73.608942
# max         99.622951

# %% [raw]
# OPERATION IN ROWS
# #calculate the sum of three column in a row

# %%
# test	User Rating	Reviews	Price	
avg=df['test'] + df['Reviews'] +  df['Price']

# %%
df.assign(Average=df['test'] + df['Reviews'] +  df['Price'])
#or df['Average']=df['test'] + df['Reviews'] +  df['Price']
# Out:
#                                                   Name  test  \
# 0                        10-Day Green Smoothie Cleanse    43
# 1                                    11/22/63: A Novel    75
# 2              12 Rules for Life: An Antidote to Chaos    13
# 3                               1984 (Signet Classics)    92
# 4    5,000 Awesome Facts (About Everything!) (Natio...    86
# ..                                                 ...   ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)    76
# 546  You Are a Badass: How to Stop Doubting Your Gr...     2
# 547  You Are a Badass: How to Stop Doubting Your Gr...     8
# 548  You Are a Badass: How to Stop Doubting Your Gr...    19
# 549  You Are a Badass: How to Stop Doubting Your Gr...    57
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# ...

# %%
df
# Out:
#                                                   Name  test  \
# 0                        10-Day Green Smoothie Cleanse    43
# 1                                    11/22/63: A Novel    75
# 2              12 Rules for Life: An Antidote to Chaos    13
# 3                               1984 (Signet Classics)    92
# 4    5,000 Awesome Facts (About Everything!) (Natio...    86
# ..                                                 ...   ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)    76
# 546  You Are a Badass: How to Stop Doubting Your Gr...     2
# 547  You Are a Badass: How to Stop Doubting Your Gr...     8
# 548  You Are a Badass: How to Stop Doubting Your Gr...    19
# 549  You Are a Badass: How to Stop Doubting Your Gr...    57
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# ...

# %%
#1 Value Counts


#counting gender elements
df['Author'].count()
# Out:
# np.int64(550)

# %%
df['Author'].value_counts()
# Out:
# Author
# Jeff Kinney                           12
# Gary Chapman                          11
# Rick Riordan                          11
# Suzanne Collins                       11
# American Psychological Association    10
#                                       ..
# Keith Richards                         1
# Chris Cleave                           1
# Alice Schertle                         1
# Celeste Ng                             1
# Adam Gasiewski                         1
# Name: count, Length: 248, dtype: int64

# %%
df['Author'].value_counts(normalize=True)
#retuen the relative frequency
# Out:
# Author
# Jeff Kinney                           0.021818
# Gary Chapman                          0.020000
# Rick Riordan                          0.020000
# Suzanne Collins                       0.020000
# American Psychological Association    0.018182
#                                         ...
# Keith Richards                        0.001818
# Chris Cleave                          0.001818
# Alice Schertle                        0.001818
# Celeste Ng                            0.001818
# Adam Gasiewski                        0.001818
# Name: proportion, Length: 248, dtype: float64

# %%
#sort by one column
df.sort_values(by='Author')
# Out:
#                                                   Name  test  \
# 56                                   Cutting for Stone     6
# 57                                   Cutting for Stone    58
# 232  Milk and Vine: Inspirational Quotes From Class...     4
# 133                               Go the F**k to Sleep    65
# 529  What Should Danny Do? (The Power to Choose Ser...    50
# ..                                                 ...   ...
# 265             Player's Handbook (Dungeons & Dragons)    69
# 266             Player's Handbook (Dungeons & Dragons)    79
# 267             Player's Handbook (Dungeons & Dragons)    61
# 78   Divine Soul Mind Body Healing and Transmission...    60
# 300  Soul Healing Miracles: Ancient and New Sacred ...    22
#
#                Author  User Rating  Reviews  Price  Year        Genre  \
# 56   Abraham Verghese          4.6     4866     11  2010      Fiction
# 57   Abraham Verghese          4.6     4866     11  2011      Fiction
# ...

# %%
df.sort_values('Year',ascending=False)
# Out:
#                                                   Name  test  \
# 549  You Are a Badass: How to Stop Doubting Your Gr...    57
# 294  School Zone - Big Preschool Workbook - Ages 4 ...    54
# 489                   The Wonderful Things You Will Be    65
# 263    P is for Potty! (Sesame Street) (Lift-the-Flap)    31
# 130  Girl, Wash Your Face: Stop Believing the Lies ...    93
# ..                                                 ...   ...
# 418  The Last Olympian (Percy Jackson and the Olymp...     6
# 38           Breaking Dawn (The Twilight Saga, Book 4)     5
# 92   Eat This, Not That! Thousands of Simple Food S...    53
# 139  Good to Great: Why Some Companies Make the Lea...    92
# 299                                  Sookie Stackhouse    74
#
#                     Author  User Rating  Reviews  Price  Year        Genre  \
# 549            Jen Sincero          4.7    14331      8  2019  Non Fiction
# 294            School Zone          4.8    23047      6  2019  Non Fiction
# ...

# %%
df.sort_values(['Year','Price'],ascending=False)
# Out:
#                                                   Name  test  \
# 267             Player's Handbook (Dungeons & Dragons)    61
# 291  Salt, Fat, Acid, Heat: Mastering the Elements ...    37
# 44   Can't Hurt Me: Master Your Mind and Defy the Odds    87
# 155  Harry Potter and the Goblet of Fire: The Illus...    32
# 171                           Howard Stern Comes Again    92
# ..                                                 ...   ...
# 25   Arguing with Idiots: How to Stop Small Minds a...    32
# 60   Dead And Gone: A Sookie Stackhouse Novel (Sook...    11
# 160                  Have a Little Faith: A True Story    90
# 388  The Girl with the Dragon Tattoo (Millennium Se...    16
# 91   Eat This Not That! Supermarket Survival Guide:...    76
#
#                Author  User Rating  Reviews  Price  Year        Genre  \
# 267  Wizards RPG Team          4.8    16990     27  2019      Fiction
# 291      Samin Nosrat          4.8     7802     20  2019  Non Fiction
# ...
